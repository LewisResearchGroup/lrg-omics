# %%
import os
from lrg_omics.proteomics.quality_control.maxquant import maxquant_qc, collect_maxquant_qc_data

# %%
PATH = os.path.join('..','tests', 'data', 'maxquant', 'tmt11', 'txt')

# %%
maxquant_qc(PATH)
# Out:
#         MS    MS/MS  MS3  MS/MS Submitted  MS/MS Identified  \
# 0  11446.0  20684.0  0.0          22656.0            7179.0
#
#    MS/MS Identified [%]  Peptide Sequences Identified  \
# 0                  32.0                        5873.0
#
#    Av. Absolute Mass Deviation [mDa]  Mass Standard Deviation [mDa]  \
# 0                           150530.0                       159940.0
#
#    N_protein_groups  ...  N_missed_cleavages_total  \
# 0            1272.0  ...                    1007.0
#
#    N_missed_cleavages_eq_0 [%]  N_missed_cleavages_eq_1 [%]  \
# 0                        82.85                        16.29
#
#    N_missed_cleavages_eq_2 [%]  N_missed_cleavages_gt_3 [%]  \
# 0                         0.85                          0.0
#
#    N_peptides_last_amino_acid_K [%]  N_peptides_last_amino_acid_R [%]  \
# 0                             66.51                             31.69
#
#    N_peptides_last_amino_acid_other [%]  Mean_parent_intensity_fraction  \
# 0                                   1.8                            0.76
#
#                                               RUNDIR
# 0  /mnt/c/Users/soere/workspace/lrg_omics/tests/d...
#
# [1 rows x 28 columns]

# %%
collect_maxquant_qc_data(PATH, force_update=True, from_csvs=False)
# Out:
#         MS    MS/MS  MS3  MS/MS Submitted  MS/MS Identified  \
# 0  11446.0  20684.0  0.0          22656.0            7179.0
#
#    MS/MS Identified [%]  Peptide Sequences Identified  \
# 0                  32.0                        5873.0
#
#    Av. Absolute Mass Deviation [mDa]  Mass Standard Deviation [mDa]  \
# 0                           150530.0                       159940.0
#
#    N_protein_groups  ...  N_missed_cleavages_total  \
# 0            1272.0  ...                    1007.0
#
#    N_missed_cleavages_eq_0 [%]  N_missed_cleavages_eq_1 [%]  \
# 0                        82.85                        16.29
#
#    N_missed_cleavages_eq_2 [%]  N_missed_cleavages_gt_3 [%]  \
# 0                         0.85                          0.0
#
#    N_peptides_last_amino_acid_K [%]  N_peptides_last_amino_acid_R [%]  \
# 0                             66.51                             31.69
#
#    N_peptides_last_amino_acid_other [%]  Mean_parent_intensity_fraction  \
# 0                                   1.8                            0.76
#
#                                               RUNDIR
# 0  /mnt/c/Users/soere/workspace/lrg_omics/tests/d...
#
# [1 rows x 28 columns]

# %%
from lrg_omics.proteomics.pipelines.maxquant import run_maxquant
